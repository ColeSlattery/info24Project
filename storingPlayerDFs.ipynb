# %%
import math
import collections
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import csv
import json

# %matplotlib inline


from nba_api.stats.endpoints import playercareerstats

from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

import pickle

# %%
nba_teams = teams.get_teams()
msList=list()
with open('NBA_Player_IDs.csv', 'r') as f:
    csvReader=csv.reader(f,delimiter=',')
    for row in csvReader:
        #print(row)
        msList.append(row)
nbaIds={}
BBRIds={}
for line in msList:
    nbaIds[line[4]]=line[6]
    BBRIds[line[0]]=line[2]

with open('scoringLeadersLystALL.pkl', 'rb') as f:
    scoringALL = pickle.load(f) # deserialize using load()

# %%
tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds['Jayson Tatum'])
nameTitle='Player_Name'

df = tmpCarreer.get_data_frames()[0]
df.insert(0,nameTitle,'Jayson Tatum')

#df['Player_Name'] = 'Jayson Tatum'
df
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0  Jayson Tatum    1628369   2017-18        00  1610612738               BOS
# 1  Jayson Tatum    1628369   2018-19        00  1610612738               BOS
# 2  Jayson Tatum    1628369   2019-20        00  1610612738               BOS
# 3  Jayson Tatum    1628369   2020-21        00  1610612738               BOS
# 4  Jayson Tatum    1628369   2021-22        00  1610612738               BOS
# 5  Jayson Tatum    1628369   2022-23        00  1610612738               BOS
# 6  Jayson Tatum    1628369   2023-24        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 0        20.0  80  80  2443.0  ...   0.826    50   352  402  128   83   58
# 1        21.0  79  79  2455.0  ...   0.855    70   407  477  168   84   57
# 2        22.0  66  66  2265.0  ...   0.812    64   396  460  200   93   57
# 3        23.0  64  64  2290.0  ...   0.868    50   422  472  276   75   31
# 4        24.0  76  76  2731.0  ...   0.853    85   524  609  334   75   49
# 5        25.0  74  74  2732.0  ...   0.854    78   571  649  342   78   51
# 6        26.0  74  74  2645.0  ...   0.833    67   534  601  364   75   43
#
#    TOV   PF   PTS
# 0  114  170  1112
# 1  122  168  1243
# 2  155  136  1547
# 3  171  122  1692
# 4  217  174  2046
# 5  213  160  2225
# 6  188  145  1987
#
# [7 rows x 28 columns]

# %%
tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds['Jaylen Brown'])
nameTitle='Player_Name'

df1 = tmpCarreer.get_data_frames()[0]
df1.insert(0,nameTitle,'Jaylen Brown')

#df['Player_Name'] = 'Jayson Tatum'
df1
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0  Jaylen Brown    1627759   2016-17        00  1610612738               BOS
# 1  Jaylen Brown    1627759   2017-18        00  1610612738               BOS
# 2  Jaylen Brown    1627759   2018-19        00  1610612738               BOS
# 3  Jaylen Brown    1627759   2019-20        00  1610612738               BOS
# 4  Jaylen Brown    1627759   2020-21        00  1610612738               BOS
# 5  Jaylen Brown    1627759   2021-22        00  1610612738               BOS
# 6  Jaylen Brown    1627759   2022-23        00  1610612738               BOS
# 7  Jaylen Brown    1627759   2023-24        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 0        20.0  78  20  1341.0  ...   0.685    45   175  220   64   35   18
# 1        21.0  70  70  2152.0  ...   0.644    66   280  346  114   70   26
# 2        22.0  74  25  1913.0  ...   0.658    65   248  313  100   69   32
# 3        23.0  57  57  1934.0  ...   0.724    62   302  364  118   65   20
# 4        24.0  58  58  1999.0  ...   0.764    71   276  347  195   72   32
# 5        25.0  66  66  2220.0  ...   0.758    53   351  404  231   70   18
# 6        26.0  67  67  2405.0  ...   0.765    78   381  459  232   75   26
# 7        27.0  70  70  2343.0  ...   0.703    84   303  387  249   83   37
#
#    TOV   PF   PTS
# 0   68  142   515
# 1  124  181  1017
# 2   99  186   964
# 3  125  167  1159
# 4  158  168  1430
# 5  178  163  1559
# 6  197  172  1784
# 7  166  185  1610
#
# [8 rows x 28 columns]

# %%
df2 = [df,df1]

# %%
df2 = pd.concat([df,df1])

df2
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0  Jayson Tatum    1628369   2017-18        00  1610612738               BOS
# 1  Jayson Tatum    1628369   2018-19        00  1610612738               BOS
# 2  Jayson Tatum    1628369   2019-20        00  1610612738               BOS
# 3  Jayson Tatum    1628369   2020-21        00  1610612738               BOS
# 4  Jayson Tatum    1628369   2021-22        00  1610612738               BOS
# 5  Jayson Tatum    1628369   2022-23        00  1610612738               BOS
# 6  Jayson Tatum    1628369   2023-24        00  1610612738               BOS
# 0  Jaylen Brown    1627759   2016-17        00  1610612738               BOS
# 1  Jaylen Brown    1627759   2017-18        00  1610612738               BOS
# 2  Jaylen Brown    1627759   2018-19        00  1610612738               BOS
# 3  Jaylen Brown    1627759   2019-20        00  1610612738               BOS
# 4  Jaylen Brown    1627759   2020-21        00  1610612738               BOS
# 5  Jaylen Brown    1627759   2021-22        00  1610612738               BOS
# 6  Jaylen Brown    1627759   2022-23        00  1610612738               BOS
# 7  Jaylen Brown    1627759   2023-24        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 0        20.0  80  80  2443.0  ...   0.826    50   352  402  128   83   58
# 1        21.0  79  79  2455.0  ...   0.855    70   407  477  168   84   57
# 2        22.0  66  66  2265.0  ...   0.812    64   396  460  200   93   57
# 3        23.0  64  64  2290.0  ...   0.868    50   422  472  276   75   31
# 4        24.0  76  76  2731.0  ...   0.853    85   524  609  334   75   49
# 5        25.0  74  74  2732.0  ...   0.854    78   571  649  342   78   51
# 6        26.0  74  74  2645.0  ...   0.833    67   534  601  364   75   43
# 0        20.0  78  20  1341.0  ...   0.685    45   175  220   64   35   18
# 1        21.0  70  70  2152.0  ...   0.644    66   280  346  114   70   26
# 2        22.0  74  25  1913.0  ...   0.658    65   248  313  100   69   32
# 3        23.0  57  57  1934.0  ...   0.724    62   302  364  118   65   20
# 4        24.0  58  58  1999.0  ...   0.764    71   276  347  195   72   32
# 5        25.0  66  66  2220.0  ...   0.758    53   351  404  231   70   18
# 6        26.0  67  67  2405.0  ...   0.765    78   381  459  232   75   26
# 7        27.0  70  70  2343.0  ...   0.703    84   303  387  249   83   37
#
#    TOV   PF   PTS
# 0  114  170  1112
# 1  122  168  1243
# 2  155  136  1547
# 3  171  122  1692
# 4  217  174  2046
# 5  213  160  2225
# 6  188  145  1987
# 0   68  142   515
# 1  124  181  1017
# 2   99  186   964
# 3  125  167  1159
# 4  158  168  1430
# 5  178  163  1559
# 6  197  172  1784
# 7  166  185  1610
#
# [15 rows x 28 columns]

# %%
scoringAllbyYear = list()
for i in range (0,9):
    scoringAllbyYear.append(scoringALL[i])
for i in range (10,13):
    for item in scoringALL[i]:
        scoringAllbyYear.append(item)
scoringAllbyYear.pop()
# Out:
# [2023]

# %%
##with open('ScoringAllByYear.pkl','wb') as f: #opens file
#    pickle.dump(scoringAllbyYear,f)

# %%
len(scoringAllbyYear)
# Out:
# 39

# %%
namesNoYears=list()
for item in scoringAllbyYear:
    for name in item:
        if type(name) == int:
            pass
        else:
            tmpName=str(name)
            tmpName= str(name.split(',')[1])+' '+str(name.split(',')[0])
            print(tmpName)
            namesNoYears.append(tmpName)
            #for char in name:    
            #    if char.isalpha() == True or char == ' ':
            #        pass
            #    else:
            #      scoringAllbyYear.remove(name)
# Out:
# George Gervin
# Moses Malone
# Julius Erving
# World B. Free
# Kareem Abdul-Jabbar
# Dan Issel
# Adrian Dantley
# Elvin Hayes
# Otis Birdsong
# Mike Mitchell
# Adrian Dantley
# Moses Malone
# George Gervin
# Kareem Abdul-Jabbar
# Julius Erving
# Mike Mitchell
# David Thompson
# Alex English
# Jamaal Wilkes
# Bernard King
# George Gervin
# Moses Malone
# Adrian Dantley
# Alex English
# Julius Erving
# Gus Williams
# Dan Issel
# Bernard King
# Kareem Abdul-Jabbar
# World B. Free
# Alex English
# Kiki Vandeweghe
# George Gervin
# Mark Aguirre
# Reggie Theus
# Moses Malone
# Joe Barry Carroll
# Larry Bird
# Isiah Thomas
# Jim Paxson
# Adrian Dantley
# Mark Aguirre
# Kiki Vandeweghe
# Alex English
# Bernard King
# George Gervin
# Larry Bird
# Terry Cummings
# Mike Mitchell
# Rolando Blackman
# Michael Jordan
# Larry Bird
# Alex English
# Dominique Wilkins
# Purvis Short
# Mark Aguirre
# Moses Malone
# Eddie Johnson
# Terry Cummings
# Mike Mitchell
# Alex English
# Dominique Wilkins
# Adrian Dantley
# Larry Bird
# Kiki Vandeweghe
# Mike Mitchell
# Kareem Abdul-Jabbar
# Jeff Malone
# Rolando Blackman
# Moses Malone
# Michael Jordan
# Alex English
# Dominique Wilkins
# Kiki Vandeweghe
# Larry Bird
# Mark Aguirre
# Dale Ellis
# Kevin McHale
# Tom Chambers
# Magic Johnson
# Michael Jordan
# Dominique Wilkins
# Larry Bird
# Karl Malone
# Charles Barkley
# Clyde Drexler
# Alex English
# Dale Ellis
# Mark Aguirre
# Hakeem Olajuwon
# Michael Jordan
# Karl Malone
# Patrick Ewing
# Chris Mullin
# David Robinson
# Dominique Wilkins
# Tim Hardaway
# Reggie Miller
# Charles Barkley
# Mitch Richmond
# Michael Jordan
# Karl Malone
# Chris Mullin
# Patrick Ewing
# Clyde Drexler
# Tim Hardaway
# Mitch Richmond
# Glen Rice
# Charles Barkley
# Scottie Pippen
# Michael Jordan
# Karl Malone
# Hakeem Olajuwon
# Dominique Wilkins
# Patrick Ewing
# Charles Barkley
# David Robinson
# Shaquille O'Neal
# Larry Johnson
# Joe Dumars
# David Robinson
# Shaquille O'Neal
# Hakeem Olajuwon
# Karl Malone
# Patrick Ewing
# Dominique Wilkins
# Mitch Richmond
# Latrell Sprewell
# Glen Rice
# Clifford Robinson
# Shaquille O'Neal
# David Robinson
# Karl Malone
# Hakeem Olajuwon
# Jamal Mashburn
# Patrick Ewing
# Mitch Richmond
# Glen Rice
# Glenn Robinson
# Scottie Pippen
# Michael Jordan
# Karl Malone
# David Robinson
# Hakeem Olajuwon
# Mitch Richmond
# Juwan Howard
# Anfernee Hardaway
# Vin Baker
# Patrick Ewing
# Glen Rice
# Michael Jordan
# Karl Malone
# Glen Rice
# Mitch Richmond
# Latrell Sprewell
# Hakeem Olajuwon
# Kendall Gill
# Allen Iverson
# Gary Payton
# Patrick Ewing
# Michael Jordan
# Karl Malone
# Antoine Walker
# Shareef Abdur-Rahim
# Glen Rice
# Michael Finley
# Allen Iverson
# Tim Duncan
# Grant Hill
# Shaquille O'Neal
# Shaquille O'Neal
# Allen Iverson
# Karl Malone
# Shareef Abdur-Rahim
# Tim Duncan
# Gary Payton
# Antonio McDyess
# Grant Hill
# Stephon Marbury
# Michael Finley
# Jerry Stackhouse
# Allen Iverson
# Shaquille O'Neal
# Paul Pierce
# Vince Carter
# Tracy McGrady
# Antawn Jamison
# Kobe Bryant
# Chris Webber
# Antoine Walker
# Paul Pierce
# Tim Duncan
# Kobe Bryant
# Tracy McGrady
# Allen Iverson
# Shaquille O'Neal
# Gary Payton
# Antoine Walker
# Karl Malone
# Dirk Nowitzki
# Kobe Bryant
# Tracy McGrady
# Allen Iverson
# Paul Pierce
# Dirk Nowitzki
# Tim Duncan
# Kevin Garnett
# Allan Houston
# Shaquille O'Neal
# Antawn Jamison
# Kevin Garnett
# Peja StojakoviÄ
# Tracy McGrady
# Paul Pierce
# Michael Redd
# Carmelo Anthony
# Dirk Nowitzki
# LeBron James
# Vince Carter
# Stephon Marbury
# Allen Iverson
# LeBron James
# Amar'e Stoudemire
# Gilbert Arenas
# Dirk Nowitzki
# Tracy McGrady
# Vince Carter
# Ray Allen
# Dwyane Wade
# Kobe Bryant
# Kobe Bryant
# LeBron James
# Allen Iverson
# Gilbert Arenas
# Dirk Nowitzki
# Carmelo Anthony
# Paul Pierce
# Dwyane Wade
# Michael Redd
# Ray Allen
# Kobe Bryant
# LeBron James
# Gilbert Arenas
# Vince Carter
# Dirk Nowitzki
# Carmelo Anthony
# Ben Gordon
# Tracy McGrady
# Allen Iverson
# Kevin Garnett
# Kobe Bryant
# LeBron James
# Allen Iverson
# Amar'e Stoudemire
# Carmelo Anthony
# Richard Jefferson
# Dirk Nowitzki
# Baron Davis
# Jason Richardson
# Joe Johnson
# Dwyane Wade
# LeBron James
# Kobe Bryant
# Dirk Nowitzki
# Kevin Durant
# Antawn Jamison
# Chris Paul
# Brandon Roy
# Chris Bosh
# Danny Granger
# Kevin Durant
# LeBron James
# Kobe Bryant
# Derrick Rose
# Amar'e Stoudemire
# Carmelo Anthony
# Dwyane Wade
# Monta Ellis
# Kevin Martin
# Blake Griffin
# Kevin Durant
# LeBron James
# Kobe Bryant
# Russell Westbrook
# Kevin Love
# Blake Griffin
# Dirk Nowitzki
# Brandon Jennings
# Carmelo Anthony
# Josh Smith
# Kevin Durant
# Kobe Bryant
# LeBron James
# James Harden
# Carmelo Anthony
# Russell Westbrook
# Stephen Curry
# Monta Ellis
# Damian Lillard
# LaMarcus Aldridge
# Kevin Durant
# Carmelo Anthony
# LeBron James
# Kevin Love
# Blake Griffin
# Stephen Curry
# James Harden
# DeMar DeRozan
# Paul George
# Dirk Nowitzki
# James Harden
# Stephen Curry
# Russell Westbrook
# LeBron James
# Damian Lillard
# Klay Thompson
# LaMarcus Aldridge
# Anthony Davis
# Kyrie Irving
# Chris Paul
# James Harden
# Stephen Curry
# Kevin Durant
# LeBron James
# Damian Lillard
# Russell Westbrook
# Paul George
# DeMar DeRozan
# Isaiah Thomas
# Klay Thompson
# Russell Westbrook
# James Harden
# Isaiah Thomas
# Anthony Davis
# Karl-Anthony Towns
# Damian Lillard
# DeMar DeRozan
# Stephen Curry
# LeBron James
# DeMarcus Cousins
# LeBron James
# James Harden
# Anthony Davis
# Russell Westbrook
# Giannis Antetokounmpo
# Damian Lillard
# Bradley Beal
# DeMar DeRozan
# Kevin Durant
# Lou Williams
# James Harden
# Paul George
# Kemba Walker
# Bradley Beal
# Damian Lillard
# Kevin Durant
# Giannis Antetokounmpo
# Stephen Curry
# Karl-Anthony Towns
# Blake Griffin
# James Harden
# Damian Lillard
# Devin Booker
# Giannis Antetokounmpo
# Trae Young
# Luka DonÄiÄ
# Bradley Beal
# LeBron James
# Donovan Mitchell
# Anthony Davis
# Stephen Curry
# Damian Lillard
# Nikola JokiÄ
# Bradley Beal
# Luka DonÄiÄ
# Giannis Antetokounmpo
# Devin Booker
# Julius Randle
# Jayson Tatum
# Zion Williamson
# Trae Young
# DeMar DeRozan
# Joel Embiid
# Jayson Tatum
# Nikola JokiÄ
# Giannis Antetokounmpo
# Luka DonÄiÄ
# Devin Booker
# Karl-Anthony Towns
# Donovan Mitchell

# %%
for item in namesNoYears:
    for char in item:    
        if char.isalpha() == True or char == ' ':
            pass
        else:
          namesNoYears.remove(item)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4     pass
#       5 else:
# ----> 6   namesNoYears.remove(item)
#
# ValueError: list.remove(x): x not in list

# %%
len(namesNoYears)
# Out:
# 366

# %%
namesNoYears
# Out:
# ['George Gervin',
#  'Moses Malone',
#  'Julius Erving',
#  'Dan Issel',
#  'Adrian Dantley',
#  'Elvin Hayes',
#  'Otis Birdsong',
#  'Mike Mitchell',
#  'Adrian Dantley',
#  'Moses Malone',
#  'George Gervin',
#  'Julius Erving',
#  'Mike Mitchell',
#  'David Thompson',
#  'Alex English',
#  'Jamaal Wilkes',
#  'Bernard King',
#  'George Gervin',
#  'Moses Malone',
#  'Adrian Dantley',
#  'Alex English',
#  'Julius Erving',
#  'Gus Williams',
#  'Dan Issel',
#  'Bernard King',
#  'World B. Free',
#  'Alex English',
#  'Kiki Vandeweghe',
#  'George Gervin',
#  'Mark Aguirre',
#  'Reggie Theus',
#  'Moses Malone',
#  'Joe Barry Carroll',
#  'Larry Bird',
#  'Isiah Thomas',
#  'Jim Paxson',
#  'Adrian Dantley',
#  'Mark Aguirre',
#  'Kiki Vandeweghe',
#  'Alex English',
#  'Bernard King',
#  'George Gervin',
#  'Larry Bird',
#  'Terry Cummings',
#  'Mike Mitchell',
#  'Rolando Blackman',
#  'Michael Jordan',
#  'Larry Bird',
#  'Alex English',
#  'Dominique Wilkins',
#  'Purvis Short',
#  'Mark Aguirre',
#  'Moses Malone',
#  'Eddie Johnson',
#  'Terry Cummings',
#  'Mike Mitchell',
#  'Alex English',
#  'Dominique Wilkins',
#  'Adrian Dantley',
#  'Larry Bird',
#  'Kiki Vandeweghe',
#  'Mike Mitchell',
#  'Kareem Abdul-Jabbar',
#  'Jeff Malone',
#  'Rolando Blackman',
#  'Moses Malone',
#  'Michael Jordan',
#  'Alex English',
#  'Dominique Wilkins',
#  'Kiki Vandeweghe',
#  'Larry Bird',
#  'Mark Aguirre',
#  'Dale Ellis',
#  'Kevin McHale',
#  'Tom Chambers',
#  'Magic Johnson',
#  'Michael Jordan',
#  'Dominique Wilkins',
#  'Larry Bird',
#  'Karl Malone',
#  'Charles Barkley',
#  'Clyde Drexler',
#  'Alex English',
#  'Dale Ellis',
#  'Mark Aguirre',
#  'Hakeem Olajuwon',
#  'Michael Jordan',
#  'Karl Malone',
#  'Patrick Ewing',
#  'Chris Mullin',
#  'David Robinson',
#  'Dominique Wilkins',
#  'Tim Hardaway',
#  'Reggie Miller',
#  'Charles Barkley',
#  'Mitch Richmond',
#  'Michael Jordan',
#  'Karl Malone',
#  'Chris Mullin',
#  'Patrick Ewing',
#  'Clyde Drexler',
#  'Tim Hardaway',
#  'Mitch Richmond',
#  'Glen Rice',
#  'Charles Barkley',
#  'Scottie Pippen',
#  'Michael Jordan',
#  'Karl Malone',
#  'Hakeem Olajuwon',
#  'Dominique Wilkins',
#  'Patrick Ewing',
#  'Charles Barkley',
#  'David Robinson',
#  'Larry Johnson',
#  'Joe Dumars',
#  'David Robinson',
#  'Hakeem Olajuwon',
#  'Karl Malone',
#  'Patrick Ewing',
#  'Dominique Wilkins',
#  'Mitch Richmond',
#  'Latrell Sprewell',
#  'Glen Rice',
#  'Clifford Robinson',
#  'David Robinson',
#  'Karl Malone',
#  'Hakeem Olajuwon',
#  'Jamal Mashburn',
#  'Patrick Ewing',
#  'Mitch Richmond',
#  'Glen Rice',
#  'Glenn Robinson',
#  'Scottie Pippen',
#  'Michael Jordan',
#  'Karl Malone',
#  'David Robinson',
#  'Hakeem Olajuwon',
#  'Mitch Richmond',
#  'Juwan Howard',
#  'Anfernee Hardaway',
#  'Vin Baker',
#  'Patrick Ewing',
#  'Glen Rice',
#  'Michael Jordan',
#  'Karl Malone',
#  'Glen Rice',
#  'Mitch Richmond',
#  'Latrell Sprewell',
#  'Hakeem Olajuwon',
#  'Kendall Gill',
#  'Allen Iverson',
#  'Gary Payton',
#  'Patrick Ewing',
#  'Michael Jordan',
#  'Karl Malone',
#  'Antoine Walker',
#  'Glen Rice',
#  'Michael Finley',
#  'Allen Iverson',
#  'Tim Duncan',
#  'Grant Hill',
#  'Allen Iverson',
#  'Karl Malone',
#  'Tim Duncan',
#  'Gary Payton',
#  'Antonio McDyess',
#  'Grant Hill',
#  'Stephon Marbury',
#  'Michael Finley',
#  'Jerry Stackhouse',
#  'Allen Iverson',
#  'Paul Pierce',
#  'Vince Carter',
#  'Tracy McGrady',
#  'Antawn Jamison',
#  'Kobe Bryant',
#  'Chris Webber',
#  'Antoine Walker',
#  'Paul Pierce',
#  'Tim Duncan',
#  'Kobe Bryant',
#  'Tracy McGrady',
#  'Allen Iverson',
#  'Gary Payton',
#  'Antoine Walker',
#  'Karl Malone',
#  'Dirk Nowitzki',
#  'Kobe Bryant',
#  'Tracy McGrady',
#  'Allen Iverson',
#  'Paul Pierce',
#  'Dirk Nowitzki',
#  'Tim Duncan',
#  'Kevin Garnett',
#  'Allan Houston',
#  "Shaquille O'Neal",
#  'Antawn Jamison',
#  'Kevin Garnett',
#  'Tracy McGrady',
#  'Paul Pierce',
#  'Michael Redd',
#  'Carmelo Anthony',
#  'Dirk Nowitzki',
#  'LeBron James',
#  'Vince Carter',
#  'Stephon Marbury',
#  'Allen Iverson',
#  'LeBron James',
#  'Gilbert Arenas',
#  'Dirk Nowitzki',
#  'Tracy McGrady',
#  'Vince Carter',
#  'Ray Allen',
#  'Dwyane Wade',
#  'Kobe Bryant',
#  'Kobe Bryant',
#  'LeBron James',
#  'Allen Iverson',
#  'Gilbert Arenas',
#  'Dirk Nowitzki',
#  'Carmelo Anthony',
#  'Paul Pierce',
#  'Dwyane Wade',
#  'Michael Redd',
#  'Ray Allen',
#  'Kobe Bryant',
#  'LeBron James',
#  'Gilbert Arenas',
#  'Vince Carter',
#  'Dirk Nowitzki',
#  'Carmelo Anthony',
#  'Ben Gordon',
#  'Tracy McGrady',
#  'Allen Iverson',
#  'Kevin Garnett',
#  'Kobe Bryant',
#  'LeBron James',
#  'Allen Iverson',
#  'Carmelo Anthony',
#  'Richard Jefferson',
#  'Dirk Nowitzki',
#  'Baron Davis',
#  'Jason Richardson',
#  'Joe Johnson',
#  'Dwyane Wade',
#  'LeBron James',
#  'Kobe Bryant',
#  'Dirk Nowitzki',
#  'Kevin Durant',
#  'Antawn Jamison',
#  'Chris Paul',
#  'Brandon Roy',
#  'Chris Bosh',
#  'Danny Granger',
#  'Kevin Durant',
#  'LeBron James',
#  'Kobe Bryant',
#  'Derrick Rose',
#  'Carmelo Anthony',
#  'Dwyane Wade',
#  'Monta Ellis',
#  'Kevin Martin',
#  'Blake Griffin',
#  'Kevin Durant',
#  'LeBron James',
#  'Kobe Bryant',
#  'Russell Westbrook',
#  'Kevin Love',
#  'Blake Griffin',
#  'Dirk Nowitzki',
#  'Brandon Jennings',
#  'Carmelo Anthony',
#  'Josh Smith',
#  'Kevin Durant',
#  'Kobe Bryant',
#  'LeBron James',
#  'James Harden',
#  'Carmelo Anthony',
#  'Russell Westbrook',
#  'Stephen Curry',
#  'Monta Ellis',
#  'Damian Lillard',
#  'LaMarcus Aldridge',
#  'Kevin Durant',
#  'Carmelo Anthony',
#  'LeBron James',
#  'Kevin Love',
#  'Blake Griffin',
#  'Stephen Curry',
#  'James Harden',
#  'DeMar DeRozan',
#  'Paul George',
#  'Dirk Nowitzki',
#  'James Harden',
#  'Stephen Curry',
#  'Russell Westbrook',
#  'LeBron James',
#  'Damian Lillard',
#  'Klay Thompson',
#  'LaMarcus Aldridge',
#  'Anthony Davis',
#  'Kyrie Irving',
#  'Chris Paul',
#  'James Harden',
#  'Stephen Curry',
#  'Kevin Durant',
#  'LeBron James',
#  'Damian Lillard',
#  'Russell Westbrook',
#  'Paul George',
#  'DeMar DeRozan',
#  'Isaiah Thomas',
#  'Klay Thompson',
#  'Russell Westbrook',
#  'James Harden',
#  'Isaiah Thomas',
#  'Anthony Davis',
#  'Damian Lillard',
#  'DeMar DeRozan',
#  'Stephen Curry',
#  'LeBron James',
#  'DeMarcus Cousins',
#  'LeBron James',
#  'James Harden',
#  'Anthony Davis',
#  'Russell Westbrook',
#  'Giannis Antetokounmpo',
#  'Damian Lillard',
#  'Bradley Beal',
#  'DeMar DeRozan',
#  'Kevin Durant',
#  'Lou Williams',
#  'James Harden',
#  'Paul George',
#  'Kemba Walker',
#  'Bradley Beal',
#  'Damian Lillard',
#  'Kevin Durant',
#  'Giannis Antetokounmpo',
#  'Stephen Curry',
#  'Blake Griffin',
#  'James Harden',
#  'Damian Lillard',
#  'Devin Booker',
#  'Giannis Antetokounmpo',
#  'Trae Young',
#  'Bradley Beal',
#  'LeBron James',
#  'Donovan Mitchell',
#  'Anthony Davis',
#  'Stephen Curry',
#  'Damian Lillard',
#  'Bradley Beal',
#  'Giannis Antetokounmpo',
#  'Devin Booker',
#  'Julius Randle',
#  'Jayson Tatum',
#  'Zion Williamson',
#  'Trae Young',
#  'DeMar DeRozan',
#  'Joel Embiid',
#  'Jayson Tatum',
#  'Giannis Antetokounmpo',
#  'Devin Booker',
#  'Karl-Anthony Towns',
#  'Donovan Mitchell']

# %%
NamesLystClean = namesNoYears

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean = pickle.load(f) # deserialize using load()

# %%
scoringAllbyYearClean
# Out:
# [['George Gervin',
#   'Moses Malone',
#   'Julius Erving',
#   'Kareem Abdul-Jabbar',
#   'Dan Issel',
#   'Adrian Dantley',
#   'Elvin Hayes',
#   'Otis Birdsong',
#   'Mike Mitchell',
#   1980],
#  ['Adrian Dantley',
#   'Moses Malone',
#   'George Gervin',
#   'Julius Erving',
#   'Mike Mitchell',
#   'David Thompson',
#   'Alex English',
#   'Jamaal Wilkes',
#   'Bernard King',
#   1981],
#  ['George Gervin',
#   'Moses Malone',
#   'Adrian Dantley',
#   'Alex English',
#   'Julius Erving',
#   'Gus Williams',
#   'Dan Issel',
#   'Bernard King',
#   'World B. Free',
#   1982],
#  ['Alex English',
#   'Kiki Vandeweghe',
#   'George Gervin',
#   'Mark Aguirre',
#   'Reggie Theus',
#   'Moses Malone',
#   'Joe Barry Carroll',
#   'Larry Bird',
#   'Isiah Thomas',
#   'Jim Paxson',
#   1983],
#  ['Adrian Dantley',
#   'Mark Aguirre',
#   'Kiki Vandeweghe',
#   'Alex English',
#   'Bernard King',
#   'George Gervin',
#   'Larry Bird',
#   'Terry Cummings',
#   'Mike Mitchell',
#   'Rolando Blackman',
#   1984],
#  ['Michael Jordan',
#   'Larry Bird',
#   'Alex English',
#   'Dominique Wilkins',
#   'Purvis Short',
#   'Mark Aguirre',
#   'Moses Malone',
#   'Eddie Johnson',
#   'Terry Cummings',
#   'Mike Mitchell',
#   1985],
#  ['Alex English',
#   'Dominique Wilkins',
#   'Adrian Dantley',
#   'Larry Bird',
#   'Kiki Vandeweghe',
#   'Mike Mitchell',
#   'Jeff Malone',
#   'Rolando Blackman',
#   'Moses Malone',
#   1986],
#  ['Michael Jordan',
#   'Alex English',
#   'Dominique Wilkins',
#   'Kiki Vandeweghe',
#   'Larry Bird',
#   'Mark Aguirre',
#   'Dale Ellis',
#   'Kevin McHale',
#   'Tom Chambers',
#   'Magic Johnson',
#   1987],
#  ['Michael Jordan',
#   'Dominique Wilkins',
#   'Larry Bird',
#   'Karl Malone',
#   'Charles Barkley',
#   'Clyde Drexler',
#   'Alex English',
#   'Dale Ellis',
#   'Mark Aguirre',
#   'Hakeem Olajuwon',
#   1988],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Chris Mullin',
#   'David Robinson',
#   'Dominique Wilkins',
#   'Tim Hardaway',
#   'Reggie Miller',
#   'Charles Barkley',
#   'Mitch Richmond',
#   1991],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Chris Mullin',
#   'Patrick Ewing',
#   'Clyde Drexler',
#   'Tim Hardaway',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Charles Barkley',
#   'Scottie Pippen',
#   1992],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Dominique Wilkins',
#   'Patrick Ewing',
#   'Charles Barkley',
#   'David Robinson',
#   'Larry Johnson',
#   'Joe Dumars',
#   1993],
#  ['David Robinson',
#   'Hakeem Olajuwon',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Dominique Wilkins',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Glen Rice',
#   'Clifford Robinson',
#   1994],
#  ['David Robinson',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Jamal Mashburn',
#   'Patrick Ewing',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Glenn Robinson',
#   'Scottie Pippen',
#   1995],
#  ['Michael Jordan',
#   'Karl Malone',
#   'David Robinson',
#   'Hakeem Olajuwon',
#   'Mitch Richmond',
#   'Juwan Howard',
#   'Anfernee Hardaway',
#   'Vin Baker',
#   'Patrick Ewing',
#   'Glen Rice',
#   1996],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Glen Rice',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Hakeem Olajuwon',
#   'Kendall Gill',
#   'Allen Iverson',
#   'Gary Payton',
#   'Patrick Ewing',
#   1997],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Antoine Walker',
#   'Glen Rice',
#   'Michael Finley',
#   'Allen Iverson',
#   'Tim Duncan',
#   'Grant Hill',
#   1998],
#  ['Allen Iverson',
#   'Karl Malone',
#   'Tim Duncan',
#   'Gary Payton',
#   'Antonio McDyess',
#   'Grant Hill',
#   'Stephon Marbury',
#   'Michael Finley',
#   1999],
#  ['Jerry Stackhouse',
#   'Allen Iverson',
#   'Paul Pierce',
#   'Vince Carter',
#   'Tracy McGrady',
#   'Antawn Jamison',
#   'Kobe Bryant',
#   'Chris Webber',
#   'Antoine Walker',
#   2001],
#  ['Paul Pierce',
#   'Tim Duncan',
#   'Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Gary Payton',
#   'Antoine Walker',
#   'Karl Malone',
#   'Dirk Nowitzki',
#   2002],
#  ['Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Paul Pierce',
#   'Dirk Nowitzki',
#   'Tim Duncan',
#   'Kevin Garnett',
#   'Allan Houston',
#   'Antawn Jamison',
#   2003],
#  ['Kevin Garnett',
#   'Tracy McGrady',
#   'Paul Pierce',
#   'Michael Redd',
#   'Carmelo Anthony',
#   'Dirk Nowitzki',
#   'LeBron James',
#   'Vince Carter',
#   'Stephon Marbury',
#   2004],
#  ['Allen Iverson',
#   'LeBron James',
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Tracy McGrady',
#   'Vince Carter',
#   'Ray Allen',
#   'Dwyane Wade',
#   'Kobe Bryant',
#   2005],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Paul Pierce',
#   'Dwyane Wade',
#   'Michael Redd',
#   'Ray Allen',
#   2006],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Gilbert Arenas',
#   'Vince Carter',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Ben Gordon',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Kevin Garnett',
#   2007],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   'Carmelo Anthony',
#   'Richard Jefferson',
#   'Dirk Nowitzki',
#   'Baron Davis',
#   'Jason Richardson',
#   'Joe Johnson',
#   2008],
#  ['Dwyane Wade',
#   'LeBron James',
#   'Kobe Bryant',
#   'Dirk Nowitzki',
#   'Kevin Durant',
#   'Antawn Jamison',
#   'Chris Paul',
#   'Brandon Roy',
#   'Chris Bosh',
#   'Danny Granger',
#   2009],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Derrick Rose',
#   'Carmelo Anthony',
#   'Dwyane Wade',
#   'Monta Ellis',
#   'Kevin Martin',
#   'Blake Griffin',
#   2011],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Russell Westbrook',
#   'Kevin Love',
#   'Blake Griffin',
#   'Dirk Nowitzki',
#   'Brandon Jennings',
#   'Carmelo Anthony',
#   'Josh Smith',
#   2012],
#  ['Kevin Durant',
#   'Kobe Bryant',
#   'LeBron James',
#   'James Harden',
#   'Carmelo Anthony',
#   'Russell Westbrook',
#   'Stephen Curry',
#   'Monta Ellis',
#   'Damian Lillard',
#   'LaMarcus Aldridge',
#   2013],
#  ['Kevin Durant',
#   'Carmelo Anthony',
#   'LeBron James',
#   'Kevin Love',
#   'Blake Griffin',
#   'Stephen Curry',
#   'James Harden',
#   'DeMar DeRozan',
#   'Paul George',
#   'Dirk Nowitzki',
#   2014],
#  ['James Harden',
#   'Stephen Curry',
#   'Russell Westbrook',
#   'LeBron James',
#   'Damian Lillard',
#   'Klay Thompson',
#   'LaMarcus Aldridge',
#   'Anthony Davis',
#   'Kyrie Irving',
#   'Chris Paul',
#   2015],
#  ['James Harden',
#   'Stephen Curry',
#   'Kevin Durant',
#   'LeBron James',
#   'Damian Lillard',
#   'Russell Westbrook',
#   'Paul George',
#   'DeMar DeRozan',
#   'Isaiah Thomas',
#   'Klay Thompson',
#   2016],
#  ['Russell Westbrook',
#   'James Harden',
#   'Isaiah Thomas',
#   'Anthony Davis',
#   'Damian Lillard',
#   'DeMar DeRozan',
#   'Stephen Curry',
#   'LeBron James',
#   'DeMarcus Cousins',
#   2017],
#  ['LeBron James',
#   'James Harden',
#   'Anthony Davis',
#   'Russell Westbrook',
#   'Giannis Antetokounmpo',
#   'Damian Lillard',
#   'Bradley Beal',
#   'DeMar DeRozan',
#   'Kevin Durant',
#   'Lou Williams',
#   2018],
#  ['James Harden',
#   'Paul George',
#   'Kemba Walker',
#   'Bradley Beal',
#   'Damian Lillard',
#   'Kevin Durant',
#   'Giannis Antetokounmpo',
#   'Stephen Curry',
#   'Blake Griffin',
#   2019],
#  ['James Harden',
#   'Damian Lillard',
#   'Devin Booker',
#   'Giannis Antetokounmpo',
#   'Trae Young',
#   'Bradley Beal',
#   'LeBron James',
#   'Donovan Mitchell',
#   'Anthony Davis',
#   2020],
#  ['Stephen Curry',
#   'Damian Lillard',
#   'Bradley Beal',
#   'Giannis Antetokounmpo',
#   'Devin Booker',
#   'Julius Randle',
#   'Jayson Tatum',
#   'Zion Williamson',
#   2021],
#  ['Trae Young',
#   'DeMar DeRozan',
#   'Joel Embiid',
#   'Jayson Tatum',
#   'Giannis Antetokounmpo',
#   'Devin Booker',
#   'Donovan Mitchell',
#   2022]]

# %%
#with open('NamesLystClean.pkl','wb') as f: #opens file
 #  pickle.dump(NamesLystClean,f)

# %%
mainDF = df

# %%
mainDF.drop([0,1,2,3,4,5,6])
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
df
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0  Jayson Tatum    1628369   2017-18        00  1610612738               BOS
# 1  Jayson Tatum    1628369   2018-19        00  1610612738               BOS
# 2  Jayson Tatum    1628369   2019-20        00  1610612738               BOS
# 3  Jayson Tatum    1628369   2020-21        00  1610612738               BOS
# 4  Jayson Tatum    1628369   2021-22        00  1610612738               BOS
# 5  Jayson Tatum    1628369   2022-23        00  1610612738               BOS
# 6  Jayson Tatum    1628369   2023-24        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 0        20.0  80  80  2443.0  ...   0.826    50   352  402  128   83   58
# 1        21.0  79  79  2455.0  ...   0.855    70   407  477  168   84   57
# 2        22.0  66  66  2265.0  ...   0.812    64   396  460  200   93   57
# 3        23.0  64  64  2290.0  ...   0.868    50   422  472  276   75   31
# 4        24.0  76  76  2731.0  ...   0.853    85   524  609  334   75   49
# 5        25.0  74  74  2732.0  ...   0.854    78   571  649  342   78   51
# 6        26.0  74  74  2645.0  ...   0.833    67   534  601  364   75   43
#
#    TOV   PF   PTS
# 0  114  170  1112
# 1  122  168  1243
# 2  155  136  1547
# 3  171  122  1692
# 4  217  174  2046
# 5  213  160  2225
# 6  188  145  1987
#
# [7 rows x 28 columns]

# %%
mainDF=df
mainDF= mainDF.drop([0,1,2,3,4,5,6])
mainDF
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
mainDF
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
scoringAllbyYearClean = scoringAllbyYear

# %%
for year in scoringAllbyYearClean:
    for name in year:
        if type(name) == int:
            pass
        else:
            tmpName=str(name)
            tmpName= str(name.split(',')[1])+' '+str(name.split(',')[0])
            year[name] = tmpName
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 8
#       6 tmpName=str(name)
#       7 tmpName= str(name.split(',')[1])+' '+str(name.split(',')[0])
# ----> 8 year[name] = tmpName
#
# TypeError: list indices must be integers or slices, not str

# %%
for year in scoringAllbyYearClean:
    for i in range(len(year)):
        if type(year[i]) == int:
            pass
        else:
            tmpName=str(year[i])
            tmpName= str(year[i].split(',')[1])+' '+str(year[i].split(',')[0])
            year[i] = tmpName

# %%
scoringAllbyYearClean
# Out:
# [['George Gervin',
#   'Moses Malone',
#   'Julius Erving',
#   'World B. Free',
#   'Kareem Abdul-Jabbar',
#   'Dan Issel',
#   'Adrian Dantley',
#   'Elvin Hayes',
#   'Otis Birdsong',
#   'Mike Mitchell',
#   1980],
#  ['Adrian Dantley',
#   'Moses Malone',
#   'George Gervin',
#   'Kareem Abdul-Jabbar',
#   'Julius Erving',
#   'Mike Mitchell',
#   'David Thompson',
#   'Alex English',
#   'Jamaal Wilkes',
#   'Bernard King',
#   1981],
#  ['George Gervin',
#   'Moses Malone',
#   'Adrian Dantley',
#   'Alex English',
#   'Julius Erving',
#   'Gus Williams',
#   'Dan Issel',
#   'Bernard King',
#   'Kareem Abdul-Jabbar',
#   'World B. Free',
#   1982],
#  ['Alex English',
#   'Kiki Vandeweghe',
#   'George Gervin',
#   'Mark Aguirre',
#   'Reggie Theus',
#   'Moses Malone',
#   'Joe Barry Carroll',
#   'Larry Bird',
#   'Isiah Thomas',
#   'Jim Paxson',
#   1983],
#  ['Adrian Dantley',
#   'Mark Aguirre',
#   'Kiki Vandeweghe',
#   'Alex English',
#   'Bernard King',
#   'George Gervin',
#   'Larry Bird',
#   'Terry Cummings',
#   'Mike Mitchell',
#   'Rolando Blackman',
#   1984],
#  ['Michael Jordan',
#   'Larry Bird',
#   'Alex English',
#   'Dominique Wilkins',
#   'Purvis Short',
#   'Mark Aguirre',
#   'Moses Malone',
#   'Eddie Johnson',
#   'Terry Cummings',
#   'Mike Mitchell',
#   1985],
#  ['Alex English',
#   'Dominique Wilkins',
#   'Adrian Dantley',
#   'Larry Bird',
#   'Kiki Vandeweghe',
#   'Mike Mitchell',
#   'Kareem Abdul-Jabbar',
#   'Jeff Malone',
#   'Rolando Blackman',
#   'Moses Malone',
#   1986],
#  ['Michael Jordan',
#   'Alex English',
#   'Dominique Wilkins',
#   'Kiki Vandeweghe',
#   'Larry Bird',
#   'Mark Aguirre',
#   'Dale Ellis',
#   'Kevin McHale',
#   'Tom Chambers',
#   'Magic Johnson',
#   1987],
#  ['Michael Jordan',
#   'Dominique Wilkins',
#   'Larry Bird',
#   'Karl Malone',
#   'Charles Barkley',
#   'Clyde Drexler',
#   'Alex English',
#   'Dale Ellis',
#   'Mark Aguirre',
#   'Hakeem Olajuwon',
#   1988],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Chris Mullin',
#   'David Robinson',
#   'Dominique Wilkins',
#   'Tim Hardaway',
#   'Reggie Miller',
#   'Charles Barkley',
#   'Mitch Richmond',
#   1991],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Chris Mullin',
#   'Patrick Ewing',
#   'Clyde Drexler',
#   'Tim Hardaway',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Charles Barkley',
#   'Scottie Pippen',
#   1992],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Dominique Wilkins',
#   'Patrick Ewing',
#   'Charles Barkley',
#   'David Robinson',
#   "Shaquille O'Neal",
#   'Larry Johnson',
#   'Joe Dumars',
#   1993],
#  ['David Robinson',
#   "Shaquille O'Neal",
#   'Hakeem Olajuwon',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Dominique Wilkins',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Glen Rice',
#   'Clifford Robinson',
#   1994],
#  ["Shaquille O'Neal",
#   'David Robinson',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Jamal Mashburn',
#   'Patrick Ewing',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Glenn Robinson',
#   'Scottie Pippen',
#   1995],
#  ['Michael Jordan',
#   'Karl Malone',
#   'David Robinson',
#   'Hakeem Olajuwon',
#   'Mitch Richmond',
#   'Juwan Howard',
#   'Anfernee Hardaway',
#   'Vin Baker',
#   'Patrick Ewing',
#   'Glen Rice',
#   1996],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Glen Rice',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Hakeem Olajuwon',
#   'Kendall Gill',
#   'Allen Iverson',
#   'Gary Payton',
#   'Patrick Ewing',
#   1997],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Antoine Walker',
#   'Shareef Abdur-Rahim',
#   'Glen Rice',
#   'Michael Finley',
#   'Allen Iverson',
#   'Tim Duncan',
#   'Grant Hill',
#   "Shaquille O'Neal",
#   1998],
#  ["Shaquille O'Neal",
#   'Allen Iverson',
#   'Karl Malone',
#   'Shareef Abdur-Rahim',
#   'Tim Duncan',
#   'Gary Payton',
#   'Antonio McDyess',
#   'Grant Hill',
#   'Stephon Marbury',
#   'Michael Finley',
#   1999],
#  ['Jerry Stackhouse',
#   'Allen Iverson',
#   "Shaquille O'Neal",
#   'Paul Pierce',
#   'Vince Carter',
#   'Tracy McGrady',
#   'Antawn Jamison',
#   'Kobe Bryant',
#   'Chris Webber',
#   'Antoine Walker',
#   2001],
#  ['Paul Pierce',
#   'Tim Duncan',
#   'Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   "Shaquille O'Neal",
#   'Gary Payton',
#   'Antoine Walker',
#   'Karl Malone',
#   'Dirk Nowitzki',
#   2002],
#  ['Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Paul Pierce',
#   'Dirk Nowitzki',
#   'Tim Duncan',
#   'Kevin Garnett',
#   'Allan Houston',
#   "Shaquille O'Neal",
#   'Antawn Jamison',
#   2003],
#  ['Kevin Garnett',
#   'Peja StojakoviÄ\x87',
#   'Tracy McGrady',
#   'Paul Pierce',
#   'Michael Redd',
#   'Carmelo Anthony',
#   'Dirk Nowitzki',
#   'LeBron James',
#   'Vince Carter',
#   'Stephon Marbury',
#   2004],
#  ['Allen Iverson',
#   'LeBron James',
#   "Amar'e Stoudemire",
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Tracy McGrady',
#   'Vince Carter',
#   'Ray Allen',
#   'Dwyane Wade',
#   'Kobe Bryant',
#   2005],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Paul Pierce',
#   'Dwyane Wade',
#   'Michael Redd',
#   'Ray Allen',
#   2006],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Gilbert Arenas',
#   'Vince Carter',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Ben Gordon',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Kevin Garnett',
#   2007],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   "Amar'e Stoudemire",
#   'Carmelo Anthony',
#   'Richard Jefferson',
#   'Dirk Nowitzki',
#   'Baron Davis',
#   'Jason Richardson',
#   'Joe Johnson',
#   2008],
#  ['Dwyane Wade',
#   'LeBron James',
#   'Kobe Bryant',
#   'Dirk Nowitzki',
#   'Kevin Durant',
#   'Antawn Jamison',
#   'Chris Paul',
#   'Brandon Roy',
#   'Chris Bosh',
#   'Danny Granger',
#   2009],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Derrick Rose',
#   "Amar'e Stoudemire",
#   'Carmelo Anthony',
#   'Dwyane Wade',
#   'Monta Ellis',
#   'Kevin Martin',
#   'Blake Griffin',
#   2011],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Russell Westbrook',
#   'Kevin Love',
#   'Blake Griffin',
#   'Dirk Nowitzki',
#   'Brandon Jennings',
#   'Carmelo Anthony',
#   'Josh Smith',
#   2012],
#  ['Kevin Durant',
#   'Kobe Bryant',
#   'LeBron James',
#   'James Harden',
#   'Carmelo Anthony',
#   'Russell Westbrook',
#   'Stephen Curry',
#   'Monta Ellis',
#   'Damian Lillard',
#   'LaMarcus Aldridge',
#   2013],
#  ['Kevin Durant',
#   'Carmelo Anthony',
#   'LeBron James',
#   'Kevin Love',
#   'Blake Griffin',
#   'Stephen Curry',
#   'James Harden',
#   'DeMar DeRozan',
#   'Paul George',
#   'Dirk Nowitzki',
#   2014],
#  ['James Harden',
#   'Stephen Curry',
#   'Russell Westbrook',
#   'LeBron James',
#   'Damian Lillard',
#   'Klay Thompson',
#   'LaMarcus Aldridge',
#   'Anthony Davis',
#   'Kyrie Irving',
#   'Chris Paul',
#   2015],
#  ['James Harden',
#   'Stephen Curry',
#   'Kevin Durant',
#   'LeBron James',
#   'Damian Lillard',
#   'Russell Westbrook',
#   'Paul George',
#   'DeMar DeRozan',
#   'Isaiah Thomas',
#   'Klay Thompson',
#   2016],
#  ['Russell Westbrook',
#   'James Harden',
#   'Isaiah Thomas',
#   'Anthony Davis',
#   'Karl-Anthony Towns',
#   'Damian Lillard',
#   'DeMar DeRozan',
#   'Stephen Curry',
#   'LeBron James',
#   'DeMarcus Cousins',
#   2017],
#  ['LeBron James',
#   'James Harden',
#   'Anthony Davis',
#   'Russell Westbrook',
#   'Giannis Antetokounmpo',
#   'Damian Lillard',
#   'Bradley Beal',
#   'DeMar DeRozan',
#   'Kevin Durant',
#   'Lou Williams',
#   2018],
#  ['James Harden',
#   'Paul George',
#   'Kemba Walker',
#   'Bradley Beal',
#   'Damian Lillard',
#   'Kevin Durant',
#   'Giannis Antetokounmpo',
#   'Stephen Curry',
#   'Karl-Anthony Towns',
#   'Blake Griffin',
#   2019],
#  ['James Harden',
#   'Damian Lillard',
#   'Devin Booker',
#   'Giannis Antetokounmpo',
#   'Trae Young',
#   'Luka DonÄ\x8diÄ\x87',
#   'Bradley Beal',
#   'LeBron James',
#   'Donovan Mitchell',
#   'Anthony Davis',
#   2020],
#  ['Stephen Curry',
#   'Damian Lillard',
#   'Nikola JokiÄ\x87',
#   'Bradley Beal',
#   'Luka DonÄ\x8diÄ\x87',
#   'Giannis Antetokounmpo',
#   'Devin Booker',
#   'Julius Randle',
#   'Jayson Tatum',
#   'Zion Williamson',
#   2021],
#  ['Trae Young',
#   'DeMar DeRozan',
#   'Joel Embiid',
#   'Jayson Tatum',
#   'Nikola JokiÄ\x87',
#   'Giannis Antetokounmpo',
#   'Luka DonÄ\x8diÄ\x87',
#   'Devin Booker',
#   'Karl-Anthony Towns',
#   'Donovan Mitchell',
#   2022]]

# %%
#with open('ScoringAllByYearClean.pkl','wb') as f: #opens file
 #   pickle.dump(scoringAllbyYearClean,f)

# %%
for year in scoringAllbyYearClean:
    for name in year:
        if type(name)== int:
            pass
        else:
            if name not in NamesLystClean:
                year.remove(name)

# %%
scoringAllbyYearClean
# Out:
# [['George Gervin',
#   'Moses Malone',
#   'Julius Erving',
#   'World B. Free',
#   'Kareem Abdul-Jabbar',
#   'Dan Issel',
#   'Adrian Dantley',
#   'Elvin Hayes',
#   'Otis Birdsong',
#   'Mike Mitchell',
#   1980],
#  ['Adrian Dantley',
#   'Moses Malone',
#   'George Gervin',
#   'Kareem Abdul-Jabbar',
#   'Julius Erving',
#   'Mike Mitchell',
#   'David Thompson',
#   'Alex English',
#   'Jamaal Wilkes',
#   'Bernard King',
#   1981],
#  ['George Gervin',
#   'Moses Malone',
#   'Adrian Dantley',
#   'Alex English',
#   'Julius Erving',
#   'Gus Williams',
#   'Dan Issel',
#   'Bernard King',
#   'Kareem Abdul-Jabbar',
#   'World B. Free',
#   1982],
#  ['Alex English',
#   'Kiki Vandeweghe',
#   'George Gervin',
#   'Mark Aguirre',
#   'Reggie Theus',
#   'Moses Malone',
#   'Joe Barry Carroll',
#   'Larry Bird',
#   'Isiah Thomas',
#   'Jim Paxson',
#   1983],
#  ['Adrian Dantley',
#   'Mark Aguirre',
#   'Kiki Vandeweghe',
#   'Alex English',
#   'Bernard King',
#   'George Gervin',
#   'Larry Bird',
#   'Terry Cummings',
#   'Mike Mitchell',
#   'Rolando Blackman',
#   1984],
#  ['Michael Jordan',
#   'Larry Bird',
#   'Alex English',
#   'Dominique Wilkins',
#   'Purvis Short',
#   'Mark Aguirre',
#   'Moses Malone',
#   'Eddie Johnson',
#   'Terry Cummings',
#   'Mike Mitchell',
#   1985],
#  ['Alex English',
#   'Dominique Wilkins',
#   'Adrian Dantley',
#   'Larry Bird',
#   'Kiki Vandeweghe',
#   'Mike Mitchell',
#   'Kareem Abdul-Jabbar',
#   'Jeff Malone',
#   'Rolando Blackman',
#   'Moses Malone',
#   1986],
#  ['Michael Jordan',
#   'Alex English',
#   'Dominique Wilkins',
#   'Kiki Vandeweghe',
#   'Larry Bird',
#   'Mark Aguirre',
#   'Dale Ellis',
#   'Kevin McHale',
#   'Tom Chambers',
#   'Magic Johnson',
#   1987],
#  ['Michael Jordan',
#   'Dominique Wilkins',
#   'Larry Bird',
#   'Karl Malone',
#   'Charles Barkley',
#   'Clyde Drexler',
#   'Alex English',
#   'Dale Ellis',
#   'Mark Aguirre',
#   'Hakeem Olajuwon',
#   1988],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Chris Mullin',
#   'David Robinson',
#   'Dominique Wilkins',
#   'Tim Hardaway',
#   'Reggie Miller',
#   'Charles Barkley',
#   'Mitch Richmond',
#   1991],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Chris Mullin',
#   'Patrick Ewing',
#   'Clyde Drexler',
#   'Tim Hardaway',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Charles Barkley',
#   'Scottie Pippen',
#   1992],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Dominique Wilkins',
#   'Patrick Ewing',
#   'Charles Barkley',
#   'David Robinson',
#   "Shaquille O'Neal",
#   'Larry Johnson',
#   'Joe Dumars',
#   1993],
#  ['David Robinson',
#   "Shaquille O'Neal",
#   'Hakeem Olajuwon',
#   'Karl Malone',
#   'Patrick Ewing',
#   'Dominique Wilkins',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Glen Rice',
#   'Clifford Robinson',
#   1994],
#  ["Shaquille O'Neal",
#   'David Robinson',
#   'Karl Malone',
#   'Hakeem Olajuwon',
#   'Jamal Mashburn',
#   'Patrick Ewing',
#   'Mitch Richmond',
#   'Glen Rice',
#   'Glenn Robinson',
#   'Scottie Pippen',
#   1995],
#  ['Michael Jordan',
#   'Karl Malone',
#   'David Robinson',
#   'Hakeem Olajuwon',
#   'Mitch Richmond',
#   'Juwan Howard',
#   'Anfernee Hardaway',
#   'Vin Baker',
#   'Patrick Ewing',
#   'Glen Rice',
#   1996],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Glen Rice',
#   'Mitch Richmond',
#   'Latrell Sprewell',
#   'Hakeem Olajuwon',
#   'Kendall Gill',
#   'Allen Iverson',
#   'Gary Payton',
#   'Patrick Ewing',
#   1997],
#  ['Michael Jordan',
#   'Karl Malone',
#   'Antoine Walker',
#   'Glen Rice',
#   'Michael Finley',
#   'Allen Iverson',
#   'Tim Duncan',
#   'Grant Hill',
#   "Shaquille O'Neal",
#   1998],
#  ["Shaquille O'Neal",
#   'Allen Iverson',
#   'Karl Malone',
#   'Tim Duncan',
#   'Gary Payton',
#   'Antonio McDyess',
#   'Grant Hill',
#   'Stephon Marbury',
#   'Michael Finley',
#   1999],
#  ['Jerry Stackhouse',
#   'Allen Iverson',
#   "Shaquille O'Neal",
#   'Paul Pierce',
#   'Vince Carter',
#   'Tracy McGrady',
#   'Antawn Jamison',
#   'Kobe Bryant',
#   'Chris Webber',
#   'Antoine Walker',
#   2001],
#  ['Paul Pierce',
#   'Tim Duncan',
#   'Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   "Shaquille O'Neal",
#   'Gary Payton',
#   'Antoine Walker',
#   'Karl Malone',
#   'Dirk Nowitzki',
#   2002],
#  ['Kobe Bryant',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Paul Pierce',
#   'Dirk Nowitzki',
#   'Tim Duncan',
#   'Kevin Garnett',
#   'Allan Houston',
#   "Shaquille O'Neal",
#   'Antawn Jamison',
#   2003],
#  ['Kevin Garnett',
#   'Tracy McGrady',
#   'Paul Pierce',
#   'Michael Redd',
#   'Carmelo Anthony',
#   'Dirk Nowitzki',
#   'LeBron James',
#   'Vince Carter',
#   'Stephon Marbury',
#   2004],
#  ['Allen Iverson',
#   'LeBron James',
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Tracy McGrady',
#   'Vince Carter',
#   'Ray Allen',
#   'Dwyane Wade',
#   'Kobe Bryant',
#   2005],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   'Gilbert Arenas',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Paul Pierce',
#   'Dwyane Wade',
#   'Michael Redd',
#   'Ray Allen',
#   2006],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Gilbert Arenas',
#   'Vince Carter',
#   'Dirk Nowitzki',
#   'Carmelo Anthony',
#   'Ben Gordon',
#   'Tracy McGrady',
#   'Allen Iverson',
#   'Kevin Garnett',
#   2007],
#  ['Kobe Bryant',
#   'LeBron James',
#   'Allen Iverson',
#   'Carmelo Anthony',
#   'Richard Jefferson',
#   'Dirk Nowitzki',
#   'Baron Davis',
#   'Jason Richardson',
#   'Joe Johnson',
#   2008],
#  ['Dwyane Wade',
#   'LeBron James',
#   'Kobe Bryant',
#   'Dirk Nowitzki',
#   'Kevin Durant',
#   'Antawn Jamison',
#   'Chris Paul',
#   'Brandon Roy',
#   'Chris Bosh',
#   'Danny Granger',
#   2009],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Derrick Rose',
#   'Carmelo Anthony',
#   'Dwyane Wade',
#   'Monta Ellis',
#   'Kevin Martin',
#   'Blake Griffin',
#   2011],
#  ['Kevin Durant',
#   'LeBron James',
#   'Kobe Bryant',
#   'Russell Westbrook',
#   'Kevin Love',
#   'Blake Griffin',
#   'Dirk Nowitzki',
#   'Brandon Jennings',
#   'Carmelo Anthony',
#   'Josh Smith',
#   2012],
#  ['Kevin Durant',
#   'Kobe Bryant',
#   'LeBron James',
#   'James Harden',
#   'Carmelo Anthony',
#   'Russell Westbrook',
#   'Stephen Curry',
#   'Monta Ellis',
#   'Damian Lillard',
#   'LaMarcus Aldridge',
#   2013],
#  ['Kevin Durant',
#   'Carmelo Anthony',
#   'LeBron James',
#   'Kevin Love',
#   'Blake Griffin',
#   'Stephen Curry',
#   'James Harden',
#   'DeMar DeRozan',
#   'Paul George',
#   'Dirk Nowitzki',
#   2014],
#  ['James Harden',
#   'Stephen Curry',
#   'Russell Westbrook',
#   'LeBron James',
#   'Damian Lillard',
#   'Klay Thompson',
#   'LaMarcus Aldridge',
#   'Anthony Davis',
#   'Kyrie Irving',
#   'Chris Paul',
#   2015],
#  ['James Harden',
#   'Stephen Curry',
#   'Kevin Durant',
#   'LeBron James',
#   'Damian Lillard',
#   'Russell Westbrook',
#   'Paul George',
#   'DeMar DeRozan',
#   'Isaiah Thomas',
#   'Klay Thompson',
#   2016],
#  ['Russell Westbrook',
#   'James Harden',
#   'Isaiah Thomas',
#   'Anthony Davis',
#   'Karl-Anthony Towns',
#   'Damian Lillard',
#   'DeMar DeRozan',
#   'Stephen Curry',
#   'LeBron James',
#   'DeMarcus Cousins',
#   2017],
#  ['LeBron James',
#   'James Harden',
#   'Anthony Davis',
#   'Russell Westbrook',
#   'Giannis Antetokounmpo',
#   'Damian Lillard',
#   'Bradley Beal',
#   'DeMar DeRozan',
#   'Kevin Durant',
#   'Lou Williams',
#   2018],
#  ['James Harden',
#   'Paul George',
#   'Kemba Walker',
#   'Bradley Beal',
#   'Damian Lillard',
#   'Kevin Durant',
#   'Giannis Antetokounmpo',
#   'Stephen Curry',
#   'Karl-Anthony Towns',
#   'Blake Griffin',
#   2019],
#  ['James Harden',
#   'Damian Lillard',
#   'Devin Booker',
#   'Giannis Antetokounmpo',
#   'Trae Young',
#   'Bradley Beal',
#   'LeBron James',
#   'Donovan Mitchell',
#   'Anthony Davis',
#   2020],
#  ['Stephen Curry',
#   'Damian Lillard',
#   'Bradley Beal',
#   'Giannis Antetokounmpo',
#   'Devin Booker',
#   'Julius Randle',
#   'Jayson Tatum',
#   'Zion Williamson',
#   2021],
#  ['Trae Young',
#   'DeMar DeRozan',
#   'Joel Embiid',
#   'Jayson Tatum',
#   'Giannis Antetokounmpo',
#   'Devin Booker',
#   'Karl-Anthony Towns',
#   'Donovan Mitchell',
#   2022]]

# %%
#with open('ScoringAllByYearClean.pkl','wb') as f: #opens file
#  pickle.dump(scoringAllbyYearClean,f)

# %%
tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds['Jayson Tatum'])
nameTitle='Player_Name'
df = tmpCarreer.get_data_frames()[0]
df.insert(0,nameTitle,'Jayson Tatum')
#df['Player_Name'] = 'Jayson Tatum'
df
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0  Jayson Tatum    1628369   2017-18        00  1610612738               BOS
# 1  Jayson Tatum    1628369   2018-19        00  1610612738               BOS
# 2  Jayson Tatum    1628369   2019-20        00  1610612738               BOS
# 3  Jayson Tatum    1628369   2020-21        00  1610612738               BOS
# 4  Jayson Tatum    1628369   2021-22        00  1610612738               BOS
# 5  Jayson Tatum    1628369   2022-23        00  1610612738               BOS
# 6  Jayson Tatum    1628369   2023-24        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 0        20.0  80  80  2443.0  ...   0.826    50   352  402  128   83   58
# 1        21.0  79  79  2455.0  ...   0.855    70   407  477  168   84   57
# 2        22.0  66  66  2265.0  ...   0.812    64   396  460  200   93   57
# 3        23.0  64  64  2290.0  ...   0.868    50   422  472  276   75   31
# 4        24.0  76  76  2731.0  ...   0.853    85   524  609  334   75   49
# 5        25.0  74  74  2732.0  ...   0.854    78   571  649  342   78   51
# 6        26.0  74  74  2645.0  ...   0.833    67   534  601  364   75   43
#
#    TOV   PF   PTS
# 0  114  170  1112
# 1  122  168  1243
# 2  155  136  1547
# 3  171  122  1692
# 4  217  174  2046
# 5  213  160  2225
# 6  188  145  1987
#
# [7 rows x 28 columns]

# %%
len(df)
df.iloc[1]
# Out:
# Player_Name          Jayson Tatum
# PLAYER_ID                 1628369
# SEASON_ID                 2018-19
# LEAGUE_ID                      00
# TEAM_ID                1610612738
# TEAM_ABBREVIATION             BOS
# PLAYER_AGE                   21.0
# GP                             79
# GS                             79
# MIN                        2455.0
# FGM                           466
# FGA                          1036
# FG_PCT                       0.45
# FG3M                          116
# FG3A                          311
# FG3_PCT                     0.373
# FTM                           195
# FTA                           228
# FT_PCT                      0.855
# OREB                           70
# DREB                          407
# REB                           477
# AST                           168
# STL                            84
# BLK                            57
# TOV                           122
# PF                            168
# PTS                          1243
# Name: 1, dtype: object

# %%
dfNeed = df2

# %%
listOfYears =list()

# %%
tmpYear1=2018
for key, value in df['SEASON_ID'].iteritems():
    #listOfYears.clear()
    print(key, value)
    if int(value[0:4]) == tmpYear1:
        print('YAY',key)
        ass = key
        if key not in listOfYears:
            listOfYears.append(ass)
print(listOfYears)

#dfass = pd.concat([df1,df['keys='])
    
# Choose entries with id p01
df_new = df[df['SEASON_ID'] == str("2018-19")]
# Out:
# 0 2017-18
# 1 2018-19
# YAY 1
# 2 2019-20
# 3 2020-21
# 4 2021-22
# 5 2022-23
# 6 2023-24
# [1]
# /var/folders/0y/bq7c7jv531171r938hd78kcc0000gn/T/ipykernel_24438/1501506676.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in df['SEASON_ID'].iteritems():

# %%
df_new
# Out:
#     Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 1  Jayson Tatum    1628369   2018-19        00  1610612738               BOS
#
#    PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 1        21.0  79  79  2455.0  ...   0.855    70   407  477  168   84   57
#
#    TOV   PF   PTS
# 1  122  168  1243
#
# [1 rows x 28 columns]

# %%
scoringAllbyYearClean[7]
# Out:
# ['Michael Jordan',
#  'Alex English',
#  'Dominique Wilkins',
#  'Kiki Vandeweghe',
#  'Larry Bird',
#  'Mark Aguirre',
#  'Dale Ellis',
#  'Kevin McHale',
#  'Tom Chambers',
#  'Magic Johnson',
#  1987]

# %%
tmpYear = 2018
tmpYear1= str(tmpYear)[2:]
tmpYear1= int(tmpYear1)+1
tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
type(tmpYear)
# Out:
# str

# %%
tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds['Jaylen Brown'])
nameTitle='Player_Name'

df1 = tmpCarreer.get_data_frames()[0]
df1.insert(0,nameTitle,'Jaylen Brown')

#df['Player_Name'] = 'Jayson Tatum'
df1

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean = pickle.load(f) # deserialize using load()

# %%
mainDF
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[0:2]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
        df1 = tmpCarreer.get_data_frames()[0]
        df1.insert(0,nameTitle,name)
        df_new = df1[df1['SEASON_ID'] == tmpYear]
        mainDF = pd.concat([mainDF,df_new])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 13
#      10 year.pop()
#      11 for name in year:
#      12     #print(name)
# ---> 13     tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
#      14     df1 = tmpCarreer.get_data_frames()[0]
#      15     df1.insert(0,nameTitle,name)
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
#     312     "LeagueID": league_id_nullable,
#     313 }
#     314 if get_request:
# --> 315     self.get_request()
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:318, in PlayerCareerStats.get_request(self)
#     317 def get_request(self):
# --> 318     self.nba_response = NBAStatsHTTP().send_api_request(
#     319         endpoint=self.endpoint,
#     320         parameters=self.parameters,
#     321         proxy=self.proxy,
#     322         headers=self.headers,
#     323         timeout=self.timeout,
#     324     )
#     325     self.load_response()
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/library/http.py:146, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     143         print("loading from file...")
#     145 if not contents:
# --> 146     response = requests.get(
#     147         url=base_url,
#     148         params=parameters,
#     149         headers=request_headers,
#     150         proxies=proxies,
#     151         timeout=timeout,
#     152     )
#     153     url = response.url
#     154     status_code = response.status_code
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# 6        Adrian Dantley      76504   1980-81        00  1610612762
# 12          Elvin Hayes      76979   1980-81        00  1610612764
# 3         Otis Birdsong      76170   1980-81        00  1610612758
# 2         Mike Mitchell      77615   1980-81        00  1610612739
# 7        Adrian Dantley      76504   1981-82        00  1610612762
# 7          Moses Malone      77449   1981-82        00  1610612745
# 5         George Gervin      76804   1981-82        00  1610612759
# 5         Julius Erving      76681   1981-82        00  1610612755
# 3         Mike Mitchell      77615   1981-82        00  1610612759
# 4         Mike Mitchell      77615   1981-82        00  1610612739
# 5         Mike Mitchell      77615   1981-82        00           0
# 5        David Thompson      78326   1981-82        00  1610612743
# 7          Alex English      76673   1981-82        00  1610612743
# 7         Jamaal Wilkes      78532   1981-82        00  1610612747
# 4          Bernard King      77264   1981-82        00  1610612744
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# 6                UTH        26.0  80  80.0  3417.0  ...   0.806  192.0  317.0
# 12               WAS        35.0  81   NaN  2931.0  ...   0.617  235.0  554.0
# 3                KCK        25.0  71  67.0  2593.0  ...   0.697  119.0  139.0
# 2                CLE        25.0  82   NaN  3194.0  ...   0.784  215.0  287.0
# 7                UTH        27.0  81  81.0  3222.0  ...   0.792  231.0  283.0
# 7                HOU        27.0  81  81.0  3398.0  ...   0.762  558.0  630.0
# 5                SAN        30.0  79  79.0  2817.0  ...   0.864  138.0  254.0
# 5                PHL        32.0  81  81.0  2789.0  ...   0.763  220.0  337.0
# 3                SAN        26.0  57  57.0  2090.0  ...   0.733  173.0  276.0
# 4                CLE        26.0  27  26.0   973.0  ...   0.720   71.0   70.0
# 5                TOT        26.0  84  83.0  3063.0  ...   0.728  244.0  346.0
# 5                DEN        27.0  61   5.0  1246.0  ...   0.814   57.0   91.0
# 7                DEN        28.0  82  82.0  3015.0  ...   0.840  210.0  348.0
# 7                LAL        29.0  82  82.0  2906.0  ...   0.732  153.0  240.0
# 4                GOS        25.0  79  77.0  2861.0  ...   0.705  140.0  329.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# 6    509  322  109.0   18.0  282.0  245  2452
# 12   789   98   68.0  171.0  189.0  300  1439
# 3    258  233   93.0   18.0  173.0  172  1747
# 2    502  139   63.0   52.0  175.0  199  2012
# 7    514  324   95.0   14.0  299.0  252  2457
# 7   1188  142   76.0  125.0  294.0  208  2520
# 5    392  187   77.0   45.0  210.0  215  2551
# 5    557  319  161.0  141.0  214.0  229  1974
# 3    449   43   33.0   28.0   98.0  200  1196
# 4    141   39   27.0   15.0   55.0   77   530
# 5    590   82   60.0   43.0  153.0  277  1726
# 5    148  117   34.0   29.0  142.0  149   906
# 7    558  433   87.0  120.0  261.0  261  2082
# 7    393  143   89.0   24.0  164.0  240  1734
# 4    469  282   78.0   23.0  267.0  285  1833
#
# [20 rows x 28 columns]

# %%
mainDF=df
mainDF= mainDF.drop([0,1,2,3,4,5,6])
mainDF
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[0:5]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File ~/anaconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File ~/anaconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     469     raise
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:357, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     356 if isinstance(err, SocketTimeout):
# --> 357     raise ReadTimeoutError(
#     358         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     359     )
#     361 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     362 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[85], line 16
#      13 for name in year:
#      14     #print(name)
#      15     try:
# ---> 16         tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
#      17         df1 = tmpCarreer.get_data_frames()[0]
#      18         df1.insert(0,nameTitle,name)
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
#     312     "LeagueID": league_id_nullable,
#     313 }
#     314 if get_request:
# --> 315     self.get_request()
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:318, in PlayerCareerStats.get_request(self)
#     317 def get_request(self):
# --> 318     self.nba_response = NBAStatsHTTP().send_api_request(
#     319         endpoint=self.endpoint,
#     320         parameters=self.parameters,
#     321         proxy=self.proxy,
#     322         headers=self.headers,
#     323         timeout=self.timeout,
#     324     )
#     325     self.load_response()
#
# File ~/anaconda3/lib/python3.11/site-packages/nba_api/library/http.py:146, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     143         print("loading from file...")
#     145 if not contents:
# --> 146     response = requests.get(
#     147         url=base_url,
#     148         params=parameters,
#     149         headers=request_headers,
#     150         proxies=proxies,
#     151         timeout=timeout,
#     152     )
#     153     url = response.url
#     154     status_code = response.status_code
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 9          Moses Malone      77449   1983-84        00  1610612755
# 3     Joe Barry Carroll      76353   1983-84        00  1610612744
# 4            Larry Bird       1449   1983-84        00  1610612738
# 2          Isiah Thomas      78318   1983-84        00  1610612765
# 4            Jim Paxson      77819   1983-84        00  1610612757
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 9                PHL        29.0  71  71.0  2613.0  ...   0.750  352.0  598.0
# 3                GOS        25.0  80  80.0  2962.0  ...   0.723  235.0  401.0
# 4                BOS        27.0  79  77.0  3028.0  ...   0.888  181.0  615.0
# 2                DET        23.0  82  82.0  3007.0  ...   0.733  103.0  224.0
# 4                POR        26.0  81  81.0  2686.0  ...   0.841   68.0  105.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 9    950   96   71.0  110.0  250.0  188  1609
# 3    636  198  103.0  142.0  268.0  244  1639
# 4    796  520  144.0   69.0  237.0  197  1908
# 2    327  914  204.0   33.0  307.0  324  1748
# 4    173  251  122.0   10.0  142.0  165  1722
#
# [333 rows x 28 columns]

# %%
mainDF1 = mainDF

# %%
#with open('scoringAllbyYearClean.pkl', 'rb') as f:
 #   scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[5:11]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 9     Dominique Wilkins       1122   1991-92        00  1610612737
# 2          Tim Hardaway        896   1991-92        00  1610612744
# 4         Reggie Miller        397   1991-92        00  1610612754
# 7       Charles Barkley        787   1991-92        00  1610612755
# 3        Mitch Richmond        782   1991-92        00  1610612758
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 9                ATL        32.0  42  42.0  1601.0  ...   0.835  103.0  192.0
# 2                GOS        25.0  81  81.0  3332.0  ...   0.766   81.0  229.0
# 4                IND        26.0  82  82.0  3120.0  ...   0.858   82.0  236.0
# 7                PHL        29.0  75  75.0  2881.0  ...   0.695  271.0  559.0
# 3                SAC        27.0  80  80.0  3095.0  ...   0.813   62.0  257.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 9    295  158   52.0   24.0  122.0   77  1179
# 2    310  807  164.0   13.0  267.0  208  1893
# 4    318  314  105.0   26.0  157.0  210  1695
# 7    830  308  136.0   44.0  235.0  196  1730
# 3    319  411   92.0   34.0  247.0  231  1803
#
# [90 rows x 28 columns]

# %%
#with open('scoringAllbyYearClean.pkl', 'rb') as f:
 #   scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[11:16]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF1 = mainDF

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 8        Mitch Richmond        782   1996-97        00  1610612758
# 2          Juwan Howard        436   1996-97        00  1610612764
# 3     Anfernee Hardaway        358   1996-97        00  1610612753
# 3             Vin Baker        452   1996-97        00  1610612749
# 7             Glen Rice        779   1996-97        00  1610612766
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 8                SAC        32.0  81  81.0  3115.0  ...   0.861   59.0  260.0
# 2                WAS        24.0  82  82.0  3318.0  ...   0.756  202.0  450.0
# 3                ORL        25.0  59  59.0  2222.0  ...   0.820   82.0  181.0
# 3                MIL        25.0  78  78.0  3156.0  ...   0.687  267.0  537.0
# 7                CHH        30.0  79  78.0  3359.0  ...   0.867   67.0  251.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 8    319  338  118.0   24.0  237.0  211  2095
# 2    652  311   93.0   23.0  246.0  259  1570
# 3    263  332   93.0   35.0  145.0  123  1210
# 3    804  211   81.0  112.0  245.0  275  1637
# 7    318  160   72.0   26.0  177.0  190  2115
#
# [124 rows x 28 columns]

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[16:21]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
#mainDF1 = mainDF
#scoringAllbyYearClean1[16:20]

# %%
mainDF1 = mainDF
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 13          Gary Payton         56   2002-03        00  1610612749
# 14          Gary Payton         56   2002-03        00           0
# 6        Antoine Walker        952   2002-03        00  1610612738
# 17          Karl Malone        252   2002-03        00  1610612762
# 4         Dirk Nowitzki       1717   2002-03        00  1610612742
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 13               MIL        34.0  28  28.0  1084.0  ...   0.746   23.0   63.0
# 14               TOT        34.0  80  80.0  3210.0  ...   0.710   79.0  255.0
# 6                BOS        26.0  78  78.0  3235.0  ...   0.615   99.0  464.0
# 17               UTA        39.0  81  81.0  2936.0  ...   0.763  113.0  515.0
# 4                DAL        25.0  80  80.0  3121.0  ...   0.881   81.0  710.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 13    86  206   40.0    8.0   56.0   64   550
# 14   334  663  133.0   20.0  187.0  181  1634
# 6    563  373  116.0   31.0  260.0  221  1570
# 17   628  379  136.0   31.0  210.0  204  1667
# 4    791  239  111.0   82.0  152.0  206  2011
#
# [151 rows x 28 columns]

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[21:26]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 4       Carmelo Anthony       2546   2007-08        00  1610612743
# 3            Ben Gordon       2732   2007-08        00  1610612741
# 10        Tracy McGrady       1503   2007-08        00  1610612745
# 13        Allen Iverson        947   2007-08        00  1610612743
# 12        Kevin Garnett        708   2007-08        00  1610612738
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 4                DEN        24.0  77  77.0  2806.0  ...   0.786  178.0  393.0
# 3                CHI        25.0  72  27.0  2291.0  ...   0.908   40.0  181.0
# 10               HOU        29.0  66  62.0  2440.0  ...   0.684   42.0  297.0
# 13               DEN        33.0  82  82.0  3424.0  ...   0.809   47.0  196.0
# 12               BOS        32.0  71  71.0  2328.0  ...   0.801  135.0  520.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 4    571  259   98.0   39.0  253.0  253  1978
# 3    221  213   55.0    8.0  150.0  171  1336
# 10   339  387   68.0   30.0  160.0   91  1427
# 13   243  586  160.0   12.0  245.0  109  2164
# 12   655  244  100.0   89.0  138.0  163  1337
#
# [193 rows x 28 columns]

# %%
with open('scoringAllbyYearClean.pkl', 'rb') as f:
    scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()

# %%
nbaIds[scoringAllbyYearClean1[21:25][0][1]]
# Out:
# '1503'

# %%
scoringAllbyYearClean1[21:25][0]
# Out:
# ['Kevin Garnett',
#  'Tracy McGrady',
#  'Paul Pierce',
#  'Michael Redd',
#  'Carmelo Anthony',
#  'Dirk Nowitzki',
#  'LeBron James',
#  'Vince Carter',
#  'Stephon Marbury',
#  2004]

# %%
tmpCarreer = playercareerstats.PlayerCareerStats(1503)
tmpYear = scoringAllbyYearClean1[21:25][0][-1]
tmpYear1= str(tmpYear)[2:]
tmpYear1= int(tmpYear1)+1
if len(str(tmpYear1))==1:
    tmpYear1 = '0'+str(tmpYear1)
tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
year.pop()
tmpYear
# Out:
# '2004-05'

# %%
tmpYear
# Out:
# '2004-5'

# %%
df1 = tmpCarreer.get_data_frames()[0]
df1.insert(0,nameTitle,name)
df_new = df1[df1['SEASON_ID'] == tmpYear]
mainDF = pd.concat([mainDF,df_new])

# %%
df_new
# Out:
# Empty DataFrame
# Columns: [Player_Name, PLAYER_ID, SEASON_ID, LEAGUE_ID, TEAM_ID, TEAM_ABBREVIATION, PLAYER_AGE, GP, GS, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 28 columns]

# %%
df1
# Out:
#       Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 0   Kevin Garnett       1503   1997-98        00  1610612761
# 1   Kevin Garnett       1503   1998-99        00  1610612761
# 2   Kevin Garnett       1503   1999-00        00  1610612761
# 3   Kevin Garnett       1503   2000-01        00  1610612753
# 4   Kevin Garnett       1503   2001-02        00  1610612753
# 5   Kevin Garnett       1503   2002-03        00  1610612753
# 6   Kevin Garnett       1503   2003-04        00  1610612753
# 7   Kevin Garnett       1503   2004-05        00  1610612745
# 8   Kevin Garnett       1503   2005-06        00  1610612745
# 9   Kevin Garnett       1503   2006-07        00  1610612745
# 10  Kevin Garnett       1503   2007-08        00  1610612745
# 11  Kevin Garnett       1503   2008-09        00  1610612745
# 12  Kevin Garnett       1503   2009-10        00  1610612745
# 13  Kevin Garnett       1503   2009-10        00  1610612752
# 14  Kevin Garnett       1503   2009-10        00           0
# 15  Kevin Garnett       1503   2010-11        00  1610612765
# 16  Kevin Garnett       1503   2011-12        00  1610612737
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP  GS     MIN  ...  FT_PCT  OREB  DREB  \
# 0                TOR        19.0  64  17  1179.0  ...   0.712   105   164
# 1                TOR        20.0  49   2  1106.0  ...   0.726   120   158
# 2                TOR        21.0  79  34  2462.0  ...   0.707   188   313
# 3                ORL        22.0  77  77  3087.0  ...   0.733   192   388
# 4                ORL        23.0  76  76  2912.0  ...   0.748   150   447
# 5                ORL        24.0  75  74  2954.0  ...   0.793   121   367
# 6                ORL        25.0  67  67  2675.0  ...   0.796    95   307
# 7                HOU        26.0  78  78  3182.0  ...   0.774    71   413
# 8                HOU        27.0  47  47  1745.0  ...   0.747    46   261
# 9                HOU        28.0  71  71  2539.0  ...   0.707    56   322
# 10               HOU        29.0  66  62  2440.0  ...   0.684    42   297
# 11               HOU        30.0  35  35  1181.0  ...   0.801    20   134
# 12               HOU        31.0   6   0    46.0  ...   0.667     0     5
# 13               NYK        31.0  24  24   627.0  ...   0.754    22    67
# 14               TOT        31.0  30  24   672.0  ...   0.746    22    72
# 15               DET        32.0  72  39  1686.0  ...   0.698    49   202
# 16               ATL        33.0  52   0   837.0  ...   0.675    23   131
#
#     REB  AST  STL  BLK  TOV   PF   PTS
# 0   269   98   49   61   66   86   451
# 1   278  113   52   66   80   94   458
# 2   501  263   90  151  160  201  1213
# 3   580  352  116  118  198  160  2065
# 4   597  400  119   73  189  139  1948
# 5   488  411  124   59  195  156  2407
# 6   402  370   93   42  179  129  1878
# 7   484  448  135   52  201  167  2003
# 8   307  225   59   41  120   88  1147
# 9   378  458   92   36  213  136  1747
# 10  339  387   68   30  160   91  1427
# 11  154  175   42   15   69   38   545
# 12    5    6    0    2    1    2    19
# 13   89   93   15   12   43   38   226
# 14   94   99   15   14   44   40   245
# 15  251  252   66   34  102  101   574
# 16  154  110   16   15   53   35   273
#
# [17 rows x 28 columns]

# %%
mainDF1 = mainDF
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 4       Carmelo Anthony       2546   2007-08        00  1610612743
# 3            Ben Gordon       2732   2007-08        00  1610612741
# 10        Tracy McGrady       1503   2007-08        00  1610612745
# 13        Allen Iverson        947   2007-08        00  1610612743
# 12        Kevin Garnett        708   2007-08        00  1610612738
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 4                DEN        24.0  77  77.0  2806.0  ...   0.786  178.0  393.0
# 3                CHI        25.0  72  27.0  2291.0  ...   0.908   40.0  181.0
# 10               HOU        29.0  66  62.0  2440.0  ...   0.684   42.0  297.0
# 13               DEN        33.0  82  82.0  3424.0  ...   0.809   47.0  196.0
# 12               BOS        32.0  71  71.0  2328.0  ...   0.801  135.0  520.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 4    571  259   98.0   39.0  253.0  253  1978
# 3    221  213   55.0    8.0  150.0  171  1336
# 10   339  387   68.0   30.0  160.0   91  1427
# 13   243  586  160.0   12.0  245.0  109  2164
# 12   655  244  100.0   89.0  138.0  163  1337
#
# [193 rows x 28 columns]

# %%
#with open('scoringAllbyYearClean.pkl', 'rb') as f:
 #   scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[26:31]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 5     Russell Westbrook     201566   2013-14        00  1610612760
# 4         Stephen Curry     201939   2013-14        00  1610612744
# 10          Monta Ellis     101145   2013-14        00  1610612742
# 1        Damian Lillard     203081   2013-14        00  1610612757
# 7     LaMarcus Aldridge     200746   2013-14        00  1610612757
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 5                OKC        25.0  46  46.0  1412.0  ...   0.826   55.0  208.0
# 4                GSW        26.0  78  78.0  2846.0  ...   0.885   46.0  288.0
# 10               DAL        28.0  82  82.0  3023.0  ...   0.788   38.0  257.0
# 1                POR        23.0  82  82.0  2937.0  ...   0.871   35.0  253.0
# 7                POR        28.0  69  69.0  2499.0  ...   0.822  166.0  599.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 5    263  319   88.0    7.0  177.0  104  1002
# 4    334  666  128.0   14.0  294.0  194  1873
# 10   295  471  141.0   23.0  264.0  197  1560
# 1    288  457   64.0   22.0  193.0  197  1695
# 7    765  178   63.0   68.0  123.0  147  1603
#
# [236 rows x 28 columns]

# %%
mainDF1=mainDF

# %%
#with open('scoringAllbyYearClean.pkl', 'rb') as f:
 #   scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[31:35]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF
# Out:
#             Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4         George Gervin      76804   1980-81        00  1610612759
# 6          Moses Malone      77449   1980-81        00  1610612745
# 4         Julius Erving      76681   1980-81        00  1610612755
# 11  Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4             Dan Issel      77097   1980-81        00  1610612743
# ..                  ...        ...       ...       ...         ...
# 5        Damian Lillard     203081   2017-18        00  1610612757
# 8         DeMar DeRozan     201942   2017-18        00  1610612761
# 8         Stephen Curry     201939   2017-18        00  1610612744
# 14         LeBron James       2544   2017-18        00  1610612739
# 9      DeMarcus Cousins     202326   2017-18        00  1610612740
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 5                POR        27.0  73  73.0  2670.0  ...   0.916   62.0  263.0
# 8                TOR        28.0  80  80.0  2712.0  ...   0.825   59.0  256.0
# 8                GSW        30.0  51  51.0  1631.0  ...   0.921   36.0  225.0
# 14               CLE        33.0  82  82.0  3026.0  ...   0.731   97.0  612.0
# 9                NOP        27.0  48  48.0  1737.0  ...   0.746  105.0  512.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 5    325  481   77.0   27.0  206.0  117  1962
# 8    315  417   85.0   22.0  175.0  151  1840
# 8    261  310   80.0    8.0  153.0  114  1346
# 14   709  747  116.0   71.0  347.0  136  2251
# 9    617  257   79.0   76.0  242.0  183  1210
#
# [267 rows x 28 columns]

# %%
mainDF1=mainDF

# %%
#with open('scoringAllbyYearClean.pkl', 'rb') as f:
 #   scoringAllbyYearClean1 = pickle.load(f) # deserialize using load()
##### BY YEAR  STUFF
nameTitle='Player_Name'
for year in scoringAllbyYearClean1[35:39]:
    tmpYear = year[-1]
    tmpYear1= str(tmpYear)[2:]
    tmpYear1= int(tmpYear1)+1
    if len(str(tmpYear1))==1:
        tmpYear1 = '0'+str(tmpYear1)
    tmpYear=(str(tmpYear)+'-'+str(tmpYear1))
    year.pop()
    for name in year:
        #print(name)
        try:
            tmpCarreer = playercareerstats.PlayerCareerStats(nbaIds[name])
            df1 = tmpCarreer.get_data_frames()[0]
            df1.insert(0,nameTitle,name)
            df_new = df1[df1['SEASON_ID'] == tmpYear]
            mainDF = pd.concat([mainDF,df_new])
        except KeyError:
            pass

# %%
mainDF
# Out:
#               Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4           George Gervin      76804   1980-81        00  1610612759
# 6            Moses Malone      77449   1980-81        00  1610612745
# 4           Julius Erving      76681   1980-81        00  1610612755
# 11    Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4               Dan Issel      77097   1980-81        00  1610612743
# ..                    ...        ...       ...       ...         ...
# 9            Bradley Beal     203078   2021-22        00  1610612764
# 8   Giannis Antetokounmpo     203507   2021-22        00  1610612749
# 6            Devin Booker    1626164   2021-22        00  1610612756
# 7           Julius Randle     203944   2021-22        00  1610612752
# 4            Jayson Tatum    1628369   2021-22        00  1610612738
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 9                WAS        29.0  40  40.0  1439.0  ...   0.833   38.0  151.0
# 8                MIL        27.0  67  67.0  2204.0  ...   0.722  134.0  644.0
# 6                PHX        25.0  68  68.0  2345.0  ...   0.868   45.0  297.0
# 7                NYK        27.0  72  72.0  2544.0  ...   0.756  125.0  591.0
# 4                BOS        24.0  76  76.0  2731.0  ...   0.853   85.0  524.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 9    189  265   36.0   15.0  135.0   95   928
# 8    778  388   72.0   91.0  219.0  212  2002
# 6    342  329   77.0   26.0  162.0  180  1822
# 7    716  370   53.0   39.0  245.0  205  1447
# 4    609  334   75.0   49.0  217.0  174  2046
#
# [293 rows x 28 columns]

# %%
mainDF2 = mainDF

# %%
mainDF2
# Out:
#               Player_Name  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 4           George Gervin      76804   1980-81        00  1610612759
# 6            Moses Malone      77449   1980-81        00  1610612745
# 4           Julius Erving      76681   1980-81        00  1610612755
# 11    Kareem Abdul-Jabbar      76003   1980-81        00  1610612747
# 4               Dan Issel      77097   1980-81        00  1610612743
# ..                    ...        ...       ...       ...         ...
# 9            Bradley Beal     203078   2021-22        00  1610612764
# 8   Giannis Antetokounmpo     203507   2021-22        00  1610612749
# 6            Devin Booker    1626164   2021-22        00  1610612756
# 7           Julius Randle     203944   2021-22        00  1610612752
# 4            Jayson Tatum    1628369   2021-22        00  1610612738
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP    GS     MIN  ...  FT_PCT   OREB   DREB  \
# 4                SAN        29.0  82   NaN  2765.0  ...   0.826  126.0  293.0
# 6                HOU        26.0  80  80.0  3245.0  ...   0.757  474.0  706.0
# 4                PHL        31.0  82   NaN  2874.0  ...   0.787  244.0  413.0
# 11               LAL        34.0  80  80.0  2976.0  ...   0.766  197.0  624.0
# 4                DEN        32.0  80   NaN  2641.0  ...   0.759  229.0  447.0
# ..               ...         ...  ..   ...     ...  ...     ...    ...    ...
# 9                WAS        29.0  40  40.0  1439.0  ...   0.833   38.0  151.0
# 8                MIL        27.0  67  67.0  2204.0  ...   0.722  134.0  644.0
# 6                PHX        25.0  68  68.0  2345.0  ...   0.868   45.0  297.0
# 7                NYK        27.0  72  72.0  2544.0  ...   0.756  125.0  591.0
# 4                BOS        24.0  76  76.0  2731.0  ...   0.853   85.0  524.0
#
#      REB  AST    STL    BLK    TOV   PF   PTS
# 4    419  260   94.0   56.0  251.0  212  2221
# 6   1180  141   83.0  150.0  308.0  223  2222
# 4    657  364  173.0  147.0  266.0  233  2014
# 11   821  272   59.0  228.0  249.0  244  2095
# 4    676  158   83.0   53.0  130.0  249  1749
# ..   ...  ...    ...    ...    ...  ...   ...
# 9    189  265   36.0   15.0  135.0   95   928
# 8    778  388   72.0   91.0  219.0  212  2002
# 6    342  329   77.0   26.0  162.0  180  1822
# 7    716  370   53.0   39.0  245.0  205  1447
# 4    609  334   75.0   49.0  217.0  174  2046
#
# [259 rows x 28 columns]

# %%
with open('mainScoringDF.pkl','wb') as f: #opens file
    pickle.dump(mainDF,f)
