# %%
import math
import collections
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import csv
import json

# %matplotlib inline

# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

# %%
msList=list()
with open('NBA_Player_IDs.csv', 'r') as f:
    csvReader=csv.reader(f,delimiter=',')
    for row in csvReader:
        #print(row)
        msList.append(row)
nbaIds={}
BBRIds={}
for line in msList:
    nbaIds[line[4]]=line[6]
    BBRIds[line[0]]=line[2]
nbaIds
# Out:
# {'NBAName': 'NBAID',
#  'AJ Hammons': '1627773',
#  'AJ Price': '201985',
#  'Aaron Brooks': '201166',
#  'Aaron Gordon': '203932',
#  'Aaron Gray': '201189',
#  'Aaron Harrison': '1626151',
#  'Aaron Holiday': '1628988',
#  'Aaron Jackson': '1628935',
#  'Abdel Nader': '1627846',
#  'Adam Morrison': '200747',
#  'Adonis Thomas': '203519',
#  'Adreian Payne': '203940',
#  'Al-Farouq Aminu': '202329',
#  'Al Harrington': '1733',
#  'Al Horford': '201143',
#  'Al Jefferson': '2744',
#  'Alan Anderson': '101187',
#  'Alan Williams': '1626210',
#  'Alec Burks': '202692',
#  'Alec Peters': '1628409',
#  'Alex Acker': '101165',
#  'Alex Caruso': '1627936',
#  'Alex Kirk': '203945',
#  'Alex Len': '203458',
#  'Alex Poythress': '1627816',
#  'Alex Stepheson': '1627293',
#  'Alexey Shved': '203144',
#  'Alfonzo McKinnie': '1628035',
#  'Alize Johnson': '1628993',
#  'Allan Houston': '275',
#  'Allen Crabbe': '203459',
#  'Allen Iverson': '947',
#  'Allonzo Trier': '1629019',
# ...

# %%
def bs(name1=str(),name2=str()):
    Name1=input("Enter the first players first and last name seperated by a space - ")
    while Name1 not in nbaIds.keys():
        print('Error, Name not recognize. Please re-enter a valid name')
        Name1=input("Enter the first players first and last name seperated by a space - ")
    Name2=input("Enter the player's first and last name to compare them to - ")
    while Name1 not in nbaIds.keys():
        print('Error, Name not recognize. Please re-enter a valid name')
        Name2=input("Enter the player's first and last name to compare them to - ")
    print(name1,name2)
    
    tmpCarreer1 = playercareerstats.PlayerCareerStats(nbaIds[name1])
    tmpCarreer2 = playercareerstats.PlayerCareerStats(nbaIds[name2])
    carreerLyst=[tmpCarreer1,tmpCarreer2]
    print(carreerLyst)
    print(name1,name2)

    return carreerLyst

# %%
test = bs()
# Out:
# Error, Name not recognize. Please re-enter a valid name
# Error, Name not recognize. Please re-enter a valid name
# Error, Name not recognize. Please re-enter a valid name
# Error, Name not recognize. Please re-enter a valid name
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 test = bs()
#
# Cell In[15], line 12, in bs(name1, name2)
#       9     Name2=input("Enter the player's first and last name to compare them to - ")
#      10 print(name1,name2)
# ---> 12 tmpCarreer1 = playercareerstats.PlayerCareerStats(nbaIds[name1])
#      13 tmpCarreer2 = playercareerstats.PlayerCareerStats(nbaIds[name2])
#      14 carreerLyst=[tmpCarreer1,tmpCarreer2]
#
# KeyError: ''
